# %% [markdown]
# # Inspect SQLite Transcript Database

# %%
from src.database.transcript_db import TranscriptDatabase

db = TranscriptDatabase()
df = db.load()

print(f"Rows : {len(df)}")
print(f"Columns: {df.columns.tolist()}")
# Out:
# 11:20:51 - INFO - Logger initialized. Log file: logs/transcript_db_20260302.log
# 11:20:51 - INFO - TranscriptDatabase ready — data/transcripts.db
# 11:20:51 - INFO - load() — returned 2 row(s).
# Rows : 2
# Columns: ['video_id', 'channel', 'channel_id', 'title', 'published_at', 'url', 'transcript', 'transcript_available']

# %%
df.head()
# Out:
#       video_id         channel                channel_id  \
# 0  p2Tigg4zyGs  TwicebakedJake  UC8FyZ-7SuPVVaoxpFOE5pvA
# 1  nP-1vDE-gWU          okJLUV  UCNzKuyNGREMYkx-vBYTDkRg
#
#                                       title          published_at  \
# 0      THE XY PREMIUM TRAINER'S COLLECTION!  2026-02-27T17:01:31Z
# 1  These Should Be Pokemon Cards (Trust Me)  2026-02-27T12:57:13Z
#
#                                            url  \
# 0  https://www.youtube.com/watch?v=p2Tigg4zyGs
# 1  https://www.youtube.com/watch?v=nP-1vDE-gWU
#
#                                           transcript  transcript_available
# 0  Hey, what's up everybody? Jake here and welcom...                  True
# 1  Here's the 30th anniversary Pokémon art you mi...                  True

# %%
df.dtypes
# Out:
# video_id                 str
# channel                  str
# channel_id               str
# title                    str
# published_at             str
# url                      str
# transcript               str
# transcript_available    bool
# dtype: object

# %%
# Transcripts available vs missing
df["transcript_available"].value_counts()
# Out:
# transcript_available
# True    2
# Name: count, dtype: int64

# %%
# Videos per channel
df.groupby("channel")["video_id"].count().rename("video_count")
# Out:
# channel
# TwicebakedJake    1
# okJLUV            1
# Name: video_count, dtype: int64

# %%
# Preview transcript text for a single video
sample = df[df["transcript_available"]].iloc[0]
print(f"Title  : {sample['title']}")
print(f"Channel: {sample['channel']}")
print(f"URL    : {sample['url']}")
print("\nTranscript preview (first 500 chars):")
print(sample["transcript"][:500])
# Out:
# Title  : THE XY PREMIUM TRAINER'S COLLECTION!
# Channel: TwicebakedJake
# URL    : https://www.youtube.com/watch?v=p2Tigg4zyGs
#
# Transcript preview (first 500 chars):
# Hey, what's up everybody? Jake here and welcome to the hobby. Today we are checking out the premium trainers XY collection. This collection box released on November 17, 2017 and its original MSRP was $99.99 and it's currently going for $1,850 on the collector's market. And so this box has climbed a ton of value, but it was actually really really poorly received on its initial release. And that's mainly due to the content it has inside of the box. So if you look inside of the box, there is two bo
